# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
#from config import g_key
g_key = "AIzaSyA1jof5KlThEyYWTmo3j0h7oCNJBMu6bco"

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head(20)
# Out:
#     City_ID            City Country  Max Temp Current Description      Lat  \
# 0         0          Katobu      ID     76.08       broken clouds  -4.9408
# 1         1       Boyolangu      ID     75.60     overcast clouds  -8.1181
# 2         2         Rikitea      PF     78.69       broken clouds -23.1203
# 3         3          Atuona      PF     78.51       broken clouds  -9.8000
# 4         4           Vaini      TO     75.36          few clouds -21.2000
# 5         5        Bengkulu      ID     77.09       moderate rain  -3.8004
# 6         6           Hobyo      SO     78.71     overcast clouds   5.3505
# 7         7           Pisco      PE     75.25           clear sky -13.7000
# 8         8         Iquique      CL     75.24           clear sky -20.2208
# 9         9       Namatanai      PG     78.49    scattered clouds  -3.6667
# 10       10  Saint-Philippe      RE     79.21       moderate rain -21.3585
# 11       11            Ende      ID     78.42     overcast clouds  -8.8432
# 12       12       Ewa Beach      US     76.69       broken clouds  21.3156
# 13       13        Chimbote      PE     78.84     overcast clouds  -9.0853
# 14       14         Kismayo      SO     78.80          few clouds  -0.3582
# 15       15       Katherine      AU     77.32       broken clouds -14.4667
# 16       16       Grenville      GD     79.29    scattered clouds  12.1167
# 17       17       Kigorobya      UG     77.07       broken clouds   1.6162
# 18       18       San Pedro      PH     79.36     overcast clouds  14.3500
# 19       19        Souillac      MU     78.78       broken clouds -20.5167
#
#          Lng                    Hotel Name
# 0   122.5276                 La Ode Husein
# 1   111.8935                    Yos ega cv
# 2  -134.9692               People ThankYou
# 3  -139.0333                   Villa Enata
# 4  -175.2000           Keleti Beach Resort
# 5   102.2655          Grage Hotel Bengkulu
# 6    48.5268   Halane Hotel and Restaurent
# 7   -76.2167      Hotel San Isidro Oficial
# 8   -70.1431   Backpacker`s Hostel Iquique
# 9   152.4333         Seagulls Inn Namatani
# 10   55.7679  Chambres d'hôte "La Trinité"
# 11  121.6623        Dwi Putra Hotel - Ende
# 12 -158.0072                  Base Lodging
# 13  -78.5783                  Hotel Briliá
# 14   42.5454                    Agan-Hotel
# 15  132.2667               Pine Tree Motel
# 16  -61.6167     Valley Breeze Guest House
# 17   31.3089  Palace guest house kigorobya
# 18  121.0167  Esquivel's Garden And Resort
# 19   57.5167   Shanti Maurice Resort & Spa

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Ende']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Ende']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Katobu']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Boyolangu'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Bengkulu'] 
print(f'Start: {vacation_start}, End: {vacation_end}')
# Out:
# Start:     City_ID  City Country  Max Temp Current Description     Lat       Lng  \
# 11       11  Ende      ID     78.42     overcast clouds -8.8432  121.6623
#
#                 Hotel Name
# 11  Dwi Putra Hotel - Ende  , End:     City_ID  City Country  Max Temp Current Description     Lat       Lng  \
# 11       11  Ende      ID     78.42     overcast clouds -8.8432  121.6623
#
#                 Hotel Name
# 11  Dwi Putra Hotel - Ende

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {stop1}, Stop 2: {stop2}, Stop 3: {stop3}')
# Out:
# Stop 1: (-4.9408, 122.5276), Stop 2: (-8.1181, 111.8935), Stop 3: (-3.8004, 102.2655)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
    start, end, waypoints=[stop1, stop2, stop3],
    travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1,vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID       City Country  Max Temp Current Description     Lat       Lng  \
# 0       11       Ende      ID     78.42     overcast clouds -8.8432  121.6623
# 1        0     Katobu      ID     76.08       broken clouds -4.9408  122.5276
# 2        1  Boyolangu      ID     75.60     overcast clouds -8.1181  111.8935
# 3        5   Bengkulu      ID     77.09       moderate rain -3.8004  102.2655
#
#                Hotel Name
# 0  Dwi Putra Hotel - Ende
# 1           La Ode Husein
# 2              Yos ega cv
# 3    Grage Hotel Bengkulu

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
