# %%
# Deliverable 1:Retrieve Weather Data
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#3 Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#4 Get the nearest city using the citipy module.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# hilo us
# ushuaia ar
# belaya gora ru
# fortuna us
# puerto ayora ec
# lagoa pt
# mys shmidta ru
# codrington ag
# qaanaaq gl
# busselton au
# lebu cl
# mataura pf
# kodiak us
# salekhard ru
# vila franca do campo pt
# zaranj af
# bowen au
# kaitangata nz
# vardo no
# bredasdorp za
# ryotsu jp
# ca mau vn
# klaksvik fo
# sapernoye ru
# mataura pf
# fairbanks us
# alice springs au
# san cristobal ec
# prachuap khiri khan th
# mackay au
# westport ie
# batagay ru
# lubango ao
# schoneiche de
# hithadhoo mv
# barentsburg sj
# mataura pf
# tiksi ru
# nikolskoye ru
# dingzhou cn
# necochea ar
# barrow us
# busselton au
# palmeira das missoes br
# paamiut gl
# cape town za
# yellowknife ca
# jamestown sh
# busselton au
# matagami ca
# ushuaia ar
# butaritari ki
# yulara au
# daura ng
# stawell au
# kendrapara in
# cape town za
# georgetown sh
# sao filipe cv
# rikitea pf
# punta arenas cl
# margate za
# llanes es
# ambon id
# rambha in
# geraldton au
# atuona pf
# narsaq gl
# tsihombe mg
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# %%
# Starting URL for Weather Map API Call.
weather_api_key="116ee4a51d63c93b7057f19480d255e9"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
city_url = url + "&q=" + "Victoria"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': 114.1577, 'lat': 22.2855},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 71.35,
#   'feels_like': 71.8,
#   'temp_min': 69.96,
#   'temp_max': 73.18,
#   'pressure': 1014,
#   'humidity': 77},
#  'visibility': 10000,
#  'wind': {'speed': 7.96, 'deg': 64, 'gust': 10.25},
#  'clouds': {'all': 15},
#  'dt': 1647117183,
#  'sys': {'type': 2,
#   'id': 2035800,
#   'country': 'HK',
#   'sunrise': 1647124470,
#   'sunset': 1647167497},
#  'timezone': 28800,
#  'id': 1819729,
#  'name': 'Hong Kong',
#  'cod': 200}

# %%
# Get the JSON data.
victoria_data = city_weather.json()

# %%
lat = victoria_data["coord"]["lat"]
lng = victoria_data["coord"]["lon"]
max_temp = victoria_data["main"]["temp_max"]
humidity = victoria_data["main"]["humidity"]
clouds = victoria_data["clouds"]["all"]
wind = victoria_data["wind"]["speed"]
conditions = victoria_data["weather"][0]['description']
print(lat, lng, max_temp, humidity, clouds, wind, conditions)
# Out:
# 22.2855 114.1577 73.18 77 15 7.96 few clouds

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_conditions})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | belaya gora
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | codrington
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | salekhard
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | zaranj
# Processing Record 17 of Set 1 | bowen
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | vardo
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | ryotsu
# ...

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo  19.7297 -155.0900     78.53        71          20
# 1       Ushuaia -54.8000  -68.3000     51.46        58          75
# 2   Belaya Gora  68.5333  146.4167    -18.11       100         100
# 3       Fortuna  40.5982 -124.1573     60.98        33         100
# 4  Puerto Ayora  -0.7393  -90.3518     85.96        70          39
# 5         Lagoa  39.0500  -27.9833     56.86        60         100
# 6    Codrington -38.2667  141.9667     54.18        83           0
# 7       Qaanaaq  77.4840  -69.3632    -14.62        73           5
# 8     Busselton -33.6500  115.3333     65.70        86          62
# 9          Lebu -37.6167  -73.6500     61.68        78           1
#
#    Wind Speed Country Current Description
# 0        5.01      US          few clouds
# 1        4.61      AR       broken clouds
# 2        1.66      RU     overcast clouds
# 3       14.97      US     overcast clouds
# ...

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US  19.7297 -155.0900     78.53        71          20
# 1       Ushuaia      AR -54.8000  -68.3000     51.46        58          75
# 2   Belaya Gora      RU  68.5333  146.4167    -18.11       100         100
# 3       Fortuna      US  40.5982 -124.1573     60.98        33         100
# 4  Puerto Ayora      EC  -0.7393  -90.3518     85.96        70          39
# 5         Lagoa      PT  39.0500  -27.9833     56.86        60         100
# 6    Codrington      AU -38.2667  141.9667     54.18        83           0
# 7       Qaanaaq      GL  77.4840  -69.3632    -14.62        73           5
# 8     Busselton      AU -33.6500  115.3333     65.70        86          62
# 9          Lebu      CL -37.6167  -73.6500     61.68        78           1
#
#    Wind Speed Current Description
# 0        5.01          few clouds
# 1        4.61       broken clouds
# 2        1.66     overcast clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "Vacation Search/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
